# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = datasets.load_diabetes()
df['feature_names']
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
# Load the diabetes dataset
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)
diabetes_X.shape
# Out:
# (442, 10)

# %%
diabetes_y.shape
# Out:
# (442,)

# %%
# Use only one feature
diabetes_X = diabetes_X[:, np.newaxis, 2]
diabetes_X.shape
# Out:
# (442, 1)

# %%
# Split the data into training/testing sets
diabetes_X_train = diabetes_X[:-20]
diabetes_X_test = diabetes_X[-20:]

# Split the targets into training/testing sets
diabetes_y_train = diabetes_y[:-20]
diabetes_y_test = diabetes_y[-20:]

# %%
# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(diabetes_X_train, diabetes_y_train)
# Out:
# LinearRegression()

# %%
# Make predictions using the testing set
diabetes_y_pred = regr.predict(diabetes_X_test)

# %%
# The coefficients
print("Coefficients: \n", regr.coef_)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(diabetes_y_test, diabetes_y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(diabetes_y_test, diabetes_y_pred))
# Out:
# Coefficients:
#  [938.23786125]
# Mean squared error: 2548.07
# Coefficient of determination: 0.47

# %%
# Plot outputs
plt.scatter(diabetes_X_test, diabetes_y_test, color="black")
plt.plot(diabetes_X_test, diabetes_y_pred, color="blue", linewidth=3)
plt.xlabel("age")
plt.ylabel("diabetes progression")
plt.xticks(())
plt.yticks(())

plt.show()

# %%
# k-means
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
np.random.seed(42)

# %%
c1=np.random.normal(loc=0,scale=1,size=(100,2))
c2=np.random.normal(loc=5,scale=1,size=(100,2))

# %%
dataset=np.vstack([c1,c2])

# %%
kmeans=KMeans(n_clusters=2,random_state=42)
kmeans.fit(dataset)
# Out:
# /home/exam/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=2, random_state=42)

# %%
labels=kmeans.labels_
centroids=kmeans.cluster_centers_

# %%
plt.scatter(dataset[:,0],dataset[:,1],c=labels,cmap='viridis',s=50,alpha=0.5)
plt.scatter(centroids[:,0],centroids[:,1],c='red',marker='X',s=200,label='Centroids')
plt.title('K-Means Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.show()
